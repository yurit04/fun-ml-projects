# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Please, write an essay on the following topic '{topic}'
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Please, rewrite the essay below addressing issues of clear structure, clarity of argument, 
    and return the revised version. 
    
    {draft}
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Please examine '{original_draft}' and it's revision '{reflection}', and 
    examine if the revision is clear, coherent, and conveys argument strength. 
    Revise again if nessessary. 
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )
    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for and Against Government Regulation of Social Media Platforms
#
# In the age of digital connectivity, social media platforms have metamorphosed from simple communication tools to powerful influencers of public opinion, commerce, and even politics. The ubiquity and influence of platforms like Facebook, Twitter, Instagram, and TikTok have raised significant questions regarding the need for government regulation. The debate on whether governments should regulate social media intersects with issues of free speech, privacy, misinformation, and corporate responsibility.
#
# Proponents of government regulation argue that it is essential for protecting users from the myriad risks associated with social media. One of the primary concerns is the rampant spread of misinformation and fake news, which can have dire consequences, ranging from skewing public perception to inciting violence. The 2016 U.S. Presidential Election serves as a salient example of how misinformation on social media can potentially undermine democratic processes. Moreover, the spread of false information about health, as witnessed during the COVID-19 pandemic, underscores the potential public health risks.
#
# Furthermore, there is an increasing need to protect user privacy and data. Social media platforms often collect vast amounts of personal data, which can be used, reused, and sometimes misused with little transparency. Government regulation could enforce stricter data protection laws, ensuring that user information is not harvested or exploited without explicit consent. This would align with frameworks like the European Union's General Data Protection Regulation (GDPR), which has set a benchmark for digital privacy.
#
# On the flip side, opponents of government regulation caution against potential overreach that could impinge on free speech. Social media platforms have been heralded for democratizing the spread of information, giving voice to marginalized communities, and enabling grassroots activism. Regulation could inadvertently stifle this free exchange of ideas, leading to censorship and the suppression of dissent. There is a delicate balance between curbing harmful content and preserving the essence of free expression that these platforms represent.
#
# Additionally, there is the risk of stifling innovation. The social media landscape is characterized by rapid technological advancements that can outpace regulatory measures. Overregulation might create an inflexible environment, hindering creativity and discouraging startups from entering the market. The dynamic nature of social media requires a flexible, adaptive regulatory approach rather than rigid mandates that could soon become obsolete.
#
# A middle ground approach could involve a combination of self-regulation by social media companies with oversight and guidance from government entities. Companies can be encouraged to enhance transparency and create robust content moderation policies while governments provide the framework for accountability. This could include third-party audits to ensure companies comply with agreed-upon standards.
#
# In conclusion, the question of whether the government should regulate social media platforms does not elicit a straightforward answer. While regulation can address significant concerns like misinformation and data privacy, it also poses risks to free speech and innovation. A nuanced approach that fosters collaboration between tech companies and government entities could strike the necessary balance, ensuring social media platforms remain spaces for safe and open dialogue while protecting users from potential harms. As the digital landscape continues to evolve, constant dialogue and adaptive measures will be essential in navigating these complex issues.
#
# 🧠 Feedback:
#
# Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
# Social media platforms—Facebook, Twitter, Instagram, TikTok, and others—have evolved from simple networking tools into powerful engines that shape public opinion, commerce, and politics. Their reach and influence raise urgent questions about the role government should play in overseeing content, protecting user data, and preserving open discourse. This essay examines the arguments for and against regulation, then proposes a balanced approach.
#
# I. Arguments in Favor of Regulation
# 1. Curbing Misinformation
# • Scope of the problem: False narratives on elections and public health can distort democratic processes and endanger lives.
# • Case in point: The 2016 U.S. presidential campaign and COVID-19 conspiracy theories illustrate how unchecked rumors on social media spread rapidly.
# • Regulatory remedy: Mandatory transparency around sources, fact-checking requirements, and penalties for platforms that allow virulent, demonstrably false claims to persist.
#
# 2. Safeguarding Privacy and Data
# • Data exploitation: Platforms routinely collect, share, and monetize personal information without users’ informed consent.
# • Existing models: The European Union’s GDPR sets a high standard for consent, data minimization, and the right to erasure.
# • Regulatory remedy: National laws mirroring GDPR principles, obligating platforms to disclose data-use practices and secure explicit user permission before sharing or selling personal information.
#
# II. Arguments Against Regulation
# 1. Threats to Free Expression
# • Democratic value: Social media democratizes voice, enabling activism and marginalized communities to reach wider audiences.
# • Risk of overreach: Broad rules could misapply to legitimate speech, leading to unwarranted censorship or chilling effects on debate.
# • Example: Ambiguous “hate speech” definitions that vary by jurisdiction might prompt platforms to remove content preemptively.
#
# 2. Innovation and Market Dynamism
# • Pace of change: Technology evolves faster than legislation, so rigid rules risk rapid obsolescence.
# • Startup hurdle: Heavy compliance costs could deter entrepreneurs, consolidating market power in a few dominant firms.
# • Alternative viewpoint: Industry-led solutions often adapt more quickly and tailor moderation tools to emerging threats.
#
# III. A Middle-Ground Solution
# 1. Co-Regulation Framework
# • Shared responsibility: Governments set guardrails and standards; platforms implement operational policies.
# • Independent oversight: Third-party audits and reporting requirements ensure compliance without direct government micromanagement.
# • Incentives for improvement: Tax breaks or certification programs could reward platforms that exceed minimal safety and transparency benchmarks.
#
# 2. Adaptive Regulation
# • Periodic review: Legislation should include sunset clauses and regular updates to match technological advances.
# • Multistakeholder input: Lawmakers, civil-society organizations, academic experts, and platform representatives collaborate on evolving guidelines.
#
# Conclusion
# The question of government regulation of social media defies a simple yes-or-no answer. On one hand, strengthened oversight can mitigate misinformation and protect user privacy; on the other, it risks stifling free speech and innovation. A nuanced, co-regulatory model—combining clear legal standards with industry-led implementation and independent audits—offers a promising path. By fostering ongoing dialogue among stakeholders and adapting rules to changing technologies, we can help ensure that social media remains both a safe space for users and a vibrant arena for expression and creativity.
#
# ✍️ Revised:
#
# The revised version is clearer and more structured than the original. It breaks down the arguments for and against government regulation of social media into organized sections, making it easy for the reader to follow. The introduction is concise and sets the stage for the arguments presented later. Each section provides well-defined points supported by examples, enhancing the overall coherence of the piece.
#
# In particular, the revision:
#
# 1. **Introduces the Main Topics Clearly:** The introduction effectively outlines the scope of the debate and what the essay will cover, which helps set clear expectations for the reader.
#
# 2. **Organizes Arguments Logically:** By dividing the arguments into sections with subheadings, the essay allows readers to easily follow the discussion. It presents points clearly under each heading, ensuring comprehensibility.
#
# 3. **Uses Evidence Effectively:** The inclusion of specific examples, such as the 2016 U.S. Presidential Election and the GDPR, strengthens the arguments by illustrating real-world implications and existing models.
#
# 4. **Presents a Balanced Perspective:** The essay explores both sides of the debate thoroughly, which adds depth to the discussion and prevents it from leaning too heavily in one direction.
#
# 5. **Proposes a Co-Regulatory Solution:** The suggested middle-ground approach is practical and optimistic, offering a path for collaboration between government and social media platforms.
#
# Despite the clarity and coherence, a few tweaks could enhance the essay further:
#
# 1. **Further Develop Counterarguments:** Strengthen the sections against regulation by providing additional concrete examples or studies demonstrating how regulation could harm innovation or free speech.
#
# 2. **Clarify the 'Shared Responsibility' Point:** The idea of shared responsibility could be elaborated on to clarify how exactly government oversight and industry implementation would work in practice.
#
# 3. **Conclude with a Stronger Call to Action:** The conclusion summarizes the arguments well, but it could benefit from a more compelling call to action or a visionary statement about the future of social media regulation.
#
# Here's a revised conclusion incorporating these suggestions:
#
# ---
#
# **Conclusion**
#
# Navigating the complexities of social media regulation requires careful consideration of both the potential benefits and the risks. Strengthened oversight can indeed mitigate misinformation and safeguard user privacy, yet the threat to free speech and innovation looms large. A nuanced, co-regulatory model—combining clear legal standards with responsive industry practices and independent audits—offers a promising avenue. By fostering ongoing, inclusive dialogue among all stakeholders and crafting adaptable regulations, we can ensure that social media remains a dynamic platform for safe, open dialogue and innovation. As our digital ecosystems evolve, so must our approaches; the future of social media lies in this collaborative balance, where safety and creativity coexist.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for and Against Government Regulation of Social Media Platforms
#
# In the age of digital connectivity, social media platforms have metamorphosed from simple communication tools to powerful influencers of public opinion, commerce, and even politics. The ubiquity and influence of platforms like Facebook, Twitter, Instagram, and TikTok have raised significant questions regarding the need for government regulation. The debate on whether governments should regulate social media intersects with issues of free speech, privacy, misinformation, and corporate responsibility.
#
# Proponents of government regulation argue that it is essential for protecting users from the myriad risks associated with social media. One of the primary concerns is the rampant spread of misinformation and fake news, which can have dire consequences, ranging from skewing public perception to inciting violence. The 2016 U.S. Presidential Election serves as a salient example of how misinformation on social media can potentially undermine democratic processes. Moreover, the spread of false information about health, as witnessed during the COVID-19 pandemic, underscores the potential public health risks.
#
# Furthermore, there is an increasing need to protect user privacy and data. Social media platforms often collect vast amounts of personal data, which can be used, reused, and sometimes misused with little transparency. Government regulation could enforce stricter data protection laws, ensuring that user information is not harvested or exploited without explicit consent. This would align with frameworks like the European Union's General Data Protection Regulation (GDPR), which has set a benchmark for digital privacy.
#
# On the flip side, opponents of government regulation caution against potential overreach that could impinge on free speech. Social media platforms have been heralded for democratizing the spread of information, giving voice to marginalized communities, and enabling grassroots activism. Regulation could inadvertently stifle this free exchange of ideas, leading to censorship and the suppression of dissent. There is a delicate balance between curbing harmful content and preserving the essence of free expression that these platforms represent.
#
# Additionally, there is the risk of stifling innovation. The social media landscape is characterized by rapid technological advancements that can outpace regulatory measures. Overregulation might create an inflexible environment, hindering creativity and discouraging startups from entering the market. The dynamic nature of social media requires a flexible, adaptive regulatory approach rather than rigid mandates that could soon become obsolete.
#
# A middle ground approach could involve a combination of self-regulation by social media companies with oversight and guidance from government entities. Companies can be encouraged to enhance transparency and create robust content moderation policies while governments provide the framework for accountability. This could include third-party audits to ensure companies comply with agreed-upon standards.
#
# In conclusion, the question of whether the government should regulate social media platforms does not elicit a straightforward answer. While regulation can address significant concerns like misinformation and data privacy, it also poses risks to free speech and innovation. A nuanced approach that fosters collaboration between tech companies and government entities could strike the necessary balance, ensuring social media platforms remain spaces for safe and open dialogue while protecting users from potential harms. As the digital landscape continues to evolve, constant dialogue and adaptive measures will be essential in navigating these complex issues.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
# Social media platforms—Facebook, Twitter, Instagram, TikTok, and others—have evolved from simple networking tools into powerful engines that shape public opinion, commerce, and politics. Their reach and influence raise urgent questions about the role government should play in overseeing content, protecting user data, and preserving open discourse. This essay examines the arguments for and against regulation, then proposes a balanced approach.
#
# I. Arguments in Favor of Regulation
# 1. Curbing Misinformation
# • Scope of the problem: False narratives on elections and public health can distort democratic processes and endanger lives.
# • Case in point: The 2016 U.S. presidential campaign and COVID-19 conspiracy theories illustrate how unchecked rumors on social media spread rapidly.
# • Regulatory remedy: Mandatory transparency around sources, fact-checking requirements, and penalties for platforms that allow virulent, demonstrably false claims to persist.
#
# 2. Safeguarding Privacy and Data
# • Data exploitation: Platforms routinely collect, share, and monetize personal information without users’ informed consent.
# • Existing models: The European Union’s GDPR sets a high standard for consent, data minimization, and the right to erasure.
# • Regulatory remedy: National laws mirroring GDPR principles, obligating platforms to disclose data-use practices and secure explicit user permission before sharing or selling personal information.
#
# II. Arguments Against Regulation
# 1. Threats to Free Expression
# • Democratic value: Social media democratizes voice, enabling activism and marginalized communities to reach wider audiences.
# • Risk of overreach: Broad rules could misapply to legitimate speech, leading to unwarranted censorship or chilling effects on debate.
# • Example: Ambiguous “hate speech” definitions that vary by jurisdiction might prompt platforms to remove content preemptively.
#
# 2. Innovation and Market Dynamism
# • Pace of change: Technology evolves faster than legislation, so rigid rules risk rapid obsolescence.
# • Startup hurdle: Heavy compliance costs could deter entrepreneurs, consolidating market power in a few dominant firms.
# • Alternative viewpoint: Industry-led solutions often adapt more quickly and tailor moderation tools to emerging threats.
#
# III. A Middle-Ground Solution
# 1. Co-Regulation Framework
# • Shared responsibility: Governments set guardrails and standards; platforms implement operational policies.
# • Independent oversight: Third-party audits and reporting requirements ensure compliance without direct government micromanagement.
# • Incentives for improvement: Tax breaks or certification programs could reward platforms that exceed minimal safety and transparency benchmarks.
#
# 2. Adaptive Regulation
# • Periodic review: Legislation should include sunset clauses and regular updates to match technological advances.
# • Multistakeholder input: Lawmakers, civil-society organizations, academic experts, and platform representatives collaborate on evolving guidelines.
#
# Conclusion
# The question of government regulation of social media defies a simple yes-or-no answer. On one hand, strengthened oversight can mitigate misinformation and protect user privacy; on the other, it risks stifling free speech and innovation. A nuanced, co-regulatory model—combining clear legal standards with industry-led implementation and independent audits—offers a promising path. By fostering ongoing dialogue among stakeholders and adapting rules to changing technologies, we can help ensure that social media remains both a safe space for users and a vibrant arena for expression and creativity.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The revised version is clearer and more structured than the original. It breaks down the arguments for and against government regulation of social media into organized sections, making it easy for the reader to follow. The introduction is concise and sets the stage for the arguments presented later. Each section provides well-defined points supported by examples, enhancing the overall coherence of the piece.
#
# In particular, the revision:
#
# 1. **Introduces the Main Topics Clearly:** The introduction effectively outlines the scope of the debate and what the essay will cover, which helps set clear expectations for the reader.
#
# 2. **Organizes Arguments Logically:** By dividing the arguments into sections with subheadings, the essay allows readers to easily follow the discussion. It presents points clearly under each heading, ensuring comprehensibility.
#
# 3. **Uses Evidence Effectively:** The inclusion of specific examples, such as the 2016 U.S. Presidential Election and the GDPR, strengthens the arguments by illustrating real-world implications and existing models.
#
# 4. **Presents a Balanced Perspective:** The essay explores both sides of the debate thoroughly, which adds depth to the discussion and prevents it from leaning too heavily in one direction.
#
# 5. **Proposes a Co-Regulatory Solution:** The suggested middle-ground approach is practical and optimistic, offering a path for collaboration between government and social media platforms.
#
# Despite the clarity and coherence, a few tweaks could enhance the essay further:
#
# 1. **Further Develop Counterarguments:** Strengthen the sections against regulation by providing additional concrete examples or studies demonstrating how regulation could harm innovation or free speech.
#
# 2. **Clarify the 'Shared Responsibility' Point:** The idea of shared responsibility could be elaborated on to clarify how exactly government oversight and industry implementation would work in practice.
#
# 3. **Conclude with a Stronger Call to Action:** The conclusion summarizes the arguments well, but it could benefit from a more compelling call to action or a visionary statement about the future of social media regulation.
#
# Here's a revised conclusion incorporating these suggestions:
#
# ---
#
# **Conclusion**
#
# Navigating the complexities of social media regulation requires careful consideration of both the potential benefits and the risks. Strengthened oversight can indeed mitigate misinformation and safeguard user privacy, yet the threat to free speech and innovation looms large. A nuanced, co-regulatory model—combining clear legal standards with responsive industry practices and independent audits—offers a promising avenue. By fostering ongoing, inclusive dialogue among all stakeholders and crafting adaptable regulations, we can ensure that social media remains a dynamic platform for safe, open dialogue and innovation. As our digital ecosystems evolve, so must our approaches; the future of social media lies in this collaborative balance, where safety and creativity coexist.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
