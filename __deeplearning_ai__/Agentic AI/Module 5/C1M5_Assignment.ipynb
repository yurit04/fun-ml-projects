# %% [markdown]
# # Graded Lab: Agentic Workflows
#
# In this lab, you will build an agentic system that generates a short research report through planning, external tool usage, and feedback integration. Your workflow will involve:
#
# ### Agents
#
# * **Planning Agent / Writer**: Creates an outline and coordinates tasks.
# * **Research Agent**: Gathers external information using tools like Arxiv, Tavily, and Wikipedia.
# * **Editor Agent**: Reflects on the report and provides suggestions for improvement.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# ### Research Tools
#
# By importing `research_tools`, you gain access to several search utilities:
#
# - `research_tools.arxiv_search_tool(query)` → search academic papers from **arXiv**
#
#   *Example:* `research_tools.arxiv_search_tool("neural networks for climate modeling")`
#
# - `research_tools.tavily_search_tool(query)` → perform web searches with the **Tavily API**
#
#   *Example:* `research_tools.tavily_search_tool("latest trends in sunglasses fashion")`
#
# - `research_tools.wikipedia_search_tool(query)` → retrieve summaries from **Wikipedia**
#
#   *Example:* `research_tools.wikipedia_search_tool("Ensemble Kalman Filter")`
#
# Run the cell below to make them available.

# %%
# =========================
# Imports
# =========================

# --- Standard library 
from datetime import datetime
import re
import json
import ast


# --- Third-party ---
from IPython.display import Markdown, display
from aisuite import Client

# --- Local / project ---
import research_tools

# %%
import unittests

# %% [markdown]
# ### Initialize client
#
# Create a shared client instance for upcoming calls.

# %%
CLIENT = Client()

# %% [markdown]
# ## Exercise 1: planner_agent
#
# ### Objective
# Correctly set up a call to a language model (LLM) to generate a research plan.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - Ensure `CLIENT.chat.completions.create` is correctly configured.
#    - Pass the `model` and `messages` parameters correctly:
#      - **Model**: Use `"openai:o4-mini"` by default.
#      - **Messages**: Set with `{"role": "user", "content": user_prompt}`.
#      - **Temperature**: Fixed at 1 for creative outputs.
#
# ### Notes
#
# - The prompt is pre-defined and guides the LLM on task requirements.
# - Only return a formatted list of steps — no extra text.
#
# Focus on the LLM call setup to complete the task.

# %%
# GRADED FUNCTION: planner_agent

def planner_agent(topic: str, model: str = "openai:o4-mini") -> list[str]:
    """
    Generates a plan as a Python list of steps (strings) for a research workflow.

    Args:
        topic (str): Research topic to investigate.
        model (str): Language model to use.

    Returns:
        List[str]: A list of executable step strings.
    """

    
    # Build the user prompt
    user_prompt = f"""
    You are a planning agent responsible for organizing a research workflow with multiple intelligent agents.

    🧠 Available agents:
    - A research agent who can search the web, Wikipedia, and arXiv.
    - A writer agent who can draft research summaries.
    - An editor agent who can reflect and revise the drafts.

    🎯 Your job is to write a clear, step-by-step research plan **as a valid Python list**, where each step is a string.
    Each step should be atomic, executable, and must rely only on the capabilities of the above agents.

    🚫 DO NOT include irrelevant tasks like "create CSV", "set up a repo", "install packages", etc.
    ✅ DO include real research-related tasks (e.g., search, summarize, draft, revise).
    ✅ DO assume tool use is available.
    ✅ DO NOT include explanation text — return ONLY the Python list.
    ✅ The final step should be to generate a Markdown document containing the complete research report.

    Topic: "{topic}"
    """

    # Add the user prompt to the messages list
    messages = [{"role": "user", "content": user_prompt}]

    ### START CODE HERE ###

    # Call the LLM
    response = CLIENT.chat.completions.create( 
        # Pass in the model
        model=model,
        # Define the messages. Remember this is meant to be a user prompt!
        messages=messages,
        # Keep responses creative
        temperature=1, 
    )

    ### END CODE HERE ###

    # Extract message from response
    steps_str = response.choices[0].message.content.strip()

    # Parse steps
    steps = ast.literal_eval(steps_str)

    return steps

# %%
# Test your code!
unittests.test_planner_agent(planner_agent)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: research_agent
#
# ### Objective
# Set up a call to a language model (LLM) to perform a research task using various tools.
#
# ### Instructions
#
# **Focus Areas**:
#
# - **Creating a Custom Prompt**:
#   - **Define the Role**: Clearly specify the role, such as "research assistant."
#   - **List Available Tools** (as strings inside the prompt, not the actual functions):
#     - Use `arxiv_tool` to find academic papers.
#     - Use `tavily_tool` for general web searches.
#     - Use `wikipedia_tool` for accessing encyclopedic knowledge.
#   - **Specify the Task**: Include a placeholder in your prompt for defining the specific task that needs to be accomplished.
#   - **Include Date Information**: Add a placeholder for the current date or time to provide context.
#
# - **Creating Messages Dict**:
#   - Ensure the `messages` are correctly set with `{"role": "user", "content": prompt}`.
#
# - **Creating Tools List**:
#   - Create a list of tools for use, such as `research_tools.arxiv_search_tool`, `research_tools.tavily_search_tool`, and `research_tools.wikipedia_search_tool`.
#
# - **Correctly Setting the Call to the LLM**:
#   - Pass the `model`, `messages`, and `tools` parameters accurately.
#   - Set `tool_choice` to `"auto"` for automatic tool selection.
#   - Limit interactions with `max_turns=6`.
#
# ### Notes
#
# - The function provides pre-coded blocks where you need to replace placeholder values.
# - The approach allows the LLM to use tools dynamically based on the task.
#
# Focus on accurately setting the messages, tools, and LLM call parameters to complete the task.

# %%
# GRADED FUNCTION: research_agent

def research_agent(task: str, model: str = "openai:gpt-4o", return_messages: bool = False):
    """
    Executes a research task using tools via aisuite (no manual loop).
    Returns either the assistant text, or (text, messages) if return_messages=True.
    """
    print("==================================")  
    print("🔍 Research Agent")                 
    print("==================================")

    current_time = datetime.now().strftime('%Y-%m-%d')
    
    ### START CODE HERE ###

    # Create a customizable prompt by defining the role (e.g., "research assistant"),
    # listing tools (arxiv_tool, tavily_tool, wikipedia_tool) for various searches,
    # specifying the task with a placeholder, and including a current_time placeholder.
    prompt = f"""
    You are a research assistant with access to multiple search tools.
    
    Available tools:
    - arxiv_tool: Search academic papers from arXiv
    - tavily_tool: Perform general web searches
    - wikipedia_tool: Access encyclopedic knowledge from Wikipedia
    
    Current date: {current_time}
    
    Task: {task}
    
    Use the appropriate tools to complete this research task thoroughly.
    """
    
    
    # Create the messages dict to pass to the LLM. Remember this is a user prompt!
    messages = [{"role": "user", "content": prompt}]


    # Save all of your available tools in the tools list. These can be found in the research_tools module.
    # You can identify each tool in your list like this: 
    # research_tools.<name_of_tool>, where <name_of_tool> is replaced with the function name of the tool.
    tools = [
        research_tools.arxiv_search_tool,
        research_tools.tavily_search_tool,
        research_tools.wikipedia_search_tool
    ]
    
    
    # Call the model with tools enabled
    response = CLIENT.chat.completions.create(  
        # Set the model
        model=model,
        # Pass in the messages. You already defined this!
        messages=messages,
        # Pass in the tools list. You already defined this!
        tools=tools,
        # Set the LLM to automatically choose the tools
        tool_choice="auto",
        # Set the max turns to 6
        max_turns=6
    )  
    
    ### END CODE HERE ###

    content = response.choices[0].message.content
    print("✅ Output:\n", content)

    
    return (content, messages) if return_messages else content

# %%
# Test your code!
unittests.test_research_agent(research_agent)
# Out:
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Here are three key references along with their summaries from different sources:
#
# 1. **ArXiv Research Papers:**
#    - **Title:** [Efficient Password-Typed Key Agreement Scheme](http://arxiv.org/abs/1002.1163v1)
#      - **Authors:** Sattar J Aboud
#      - **Summary:** This paper critiques the Lee, Kim, and Yoo password-typed key agreement scheme, identifying its security flaws. It proposes an enhanced variant that is more secure and efficient, resisting attacks like password guessing and stolen verifier attacks.
#      - [PDF Link](https://arxiv.org/pdf/1002.1163v1)
#
#    - **Title:** [Integrating HCI Datasets in Project-Based Machine Learning Courses: A College-Level Review and Case Study](http://arxiv.org/abs/2408.03472v1)
#      - **Authors:** Xiaodong Qu, Matthew Key, Eric Luo, Chuhui Qiu
#      - **Summary:** This study reviews methods to integrate HCI datasets in machine learning courses, highlighting improvements in student engagement and skill development. It suggests a framework for effectively incorporating real-world ML projects into education, addressing challenges such as data complexity.
#      - [PDF Link](https://arxiv.org/pdf/2408.03472v1)
#
#    - **Title:** [New protocols for quantum key distribution with explicit upper and lower bound on secret key rate](http://arxiv.org/abs/2212.13089v3)
#      - **Authors:** Arindam Dutta, Anirban Pathak
#      - **Summary:** Introducing two quantum key distribution schemes that improve efficiency without needing entanglement. It proves secure against various attacks, offering bounds on key rates and suggesting classical pre-processing to enhance security. It surpasses existing protocols like SARG04 in efficiency.
#      - [PDF Link](https://arxiv.org/pdf/2212.13089v3)
#
# 2. **Tavily Search Results:**
#    - [Key references - ResearchGate](https://www.researchgate.net/publication/306362593_Key_references): A publication by Kihong Kim that discusses key references and their utilization in research.
#    - [Topic: Summaries & cross-references | Referencing - LearnOnline](https://lo.unisa.edu.au/course/view.php?id=3839&sectionid=555852): Guidance on summarizing sources in your own words to express understanding of the original author's arguments.
#    - [References in Executive Summary? - Academia Stack Exchange](https://academia.stackexchange.com/questions/14656/references-in-executive-summary): Discussion around the inclusion of references in executive summaries, recommending against excessive formality for clarity.
#
# 3. **Wikipedia:**
#    - Unfortunately, an error occurred finding a Wikipedia page specifically summarizing "key references". Further searches might be needed for more detailed summaries from Wikipedia.
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  The search for seminal papers yielded from arXiv resulted in interesting findings. One paper titled "Back to the seminal Deutsch algorithm" by Giuseppe Castagnoli, published in 2017, highlights a seminal quantum algorithm devised by Deutsch. This paper aims not only to introduce quantum computing but also to foster interdisciplinary research in the field. However, the search also returned a withdrawn paper without substantial content. Meanwhile, general web resources emphasize the importance of seminal papers, describing them as pivotal works that redefine research priorities and open new areas of inquiry. These papers are often foundational or central to the development of a research area and are frequently cited in subsequent scholarly works. Understanding and citing these works is crucial for advancing knowledge and conducting thorough academic research.
#  All tests passed!

# %% [markdown]
# ## Exercise 3: writer_agent
#
# ### Objective
# Set up a call to a language model (LLM) for executing writing tasks like drafting, expanding, or summarizing text.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of a writing agent focused on generating academic or technical content.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The function is designed to produce well-structured text by setting the correct prompts.
# - Temperature is set to 1.0 to allow for creative variance in the writing outputs.
#
# Ensure the system prompt and messages are defined properly to achieve a structured output from the LLM.

# %%
# GRADED FUNCTION: writer_agent
def writer_agent(task: str, model: str = "openai:gpt-4o") -> str: # @REPLACE def writer_agent(task: str, model: str = None) -> str:
    """
    Executes writing tasks, such as drafting, expanding, or summarizing text.
    """
    print("==================================")
    print("✍️ Writer Agent")
    print("==================================")

    ### START CODE HERE ###
    
    # Create the system prompt.
    # This should assign the LLM the role of a writing agent specialized in generating well-structured academic or technical content
    system_prompt = "You are a writing agent specialized in generating well-structured academic and technical content. Your role is to draft, expand, and summarize text with clarity and precision."


    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}


    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}


    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###

    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=1.0
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_writer_agent(writer_agent)
# Out:
# ==================================
# ✍️ Writer Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ## Exercise 4: editor_agent
#
# ### Objective
# Configure a call to a language model (LLM) to perform editorial tasks such as reflecting, critiquing, or revising drafts.
#
# ### Instructions
#
# 1. **Focus Areas**:
#    - **System Prompt**:
#      - Define `system_prompt` to assign the LLM the role of an editor agent whose task is to reflect on, critique, or improve drafts.
#    - **System and User Messages**:
#      - Create `system_msg` using `{"role": "system", "content": system_prompt}`.
#      - Create `user_msg` using `{"role": "user", "content": task}`.
#    - **Messages List**:
#      - Combine `system_msg` and `user_msg` into a `messages` list.
#
# ### Notes
#
# - The editor agent is tailored for enhancing the quality of text by setting an appropriate role and task in the prompts.
# - Temperature is set to 0.7, balancing creativity and coherence in editorial outputs.
#
# Ensure the system prompt and messages are accurately set up to perform effective editorial tasks with the LLM.

# %%
# GRADED FUNCTION: editor_agent
def editor_agent(task: str, model: str = "openai:gpt-4o") -> str:
    """
    Executes editorial tasks such as reflection, critique, or revision.
    """
    print("==================================")
    print("🧠 Editor Agent")
    print("==================================")
    
    ### START CODE HERE ###

    # Create the system prompt.
    # This should assign the LLM the role of an editor agent specialized in reflecting on, critiquing, or improving existing drafts.
    system_prompt = "You are an editor agent specialized in reflecting on, critiquing, and improving existing drafts. Your role is to provide constructive feedback and revise content to enhance clarity, coherence, and quality."
    
    
    # Define the system msg by using the system_prompt and assigning the role of system
    system_msg = {"role": "system", "content": system_prompt}
    
    
    # Define the user msg. In this case the user prompt should be the task passed to the function
    user_msg = {"role": "user", "content": task}
    
    
    # Add both system and user messages to the messages list
    messages = [system_msg, user_msg]
    
    ### END CODE HERE ###
    
    response = CLIENT.chat.completions.create(
        model=model, 
        messages=messages,
        temperature=0.7 
    )
    
    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_editor_agent(editor_agent)
# Out:
# ==================================
# 🧠 Editor Agent
# ==================================
#  All tests passed!

# %% [markdown]
# ### 🎯 The Executor Agent
#
# The `executor_agent` manages the workflow by executing each step of a given plan. It:
#
# 1. Decides **which agent** (`research_agent`, `writer_agent`, or `editor_agent`) should handle the step.
# 2. Builds context from the outputs of previous steps.
# 3. Sends the enriched task to the selected agent.
# 4. Collects and stores the results in a shared history.
#
# 👉 **Do not implement or modify this function.** It is already provided as the orchestration component of the multi-agent pipeline.
#
# Notice that `planner_agent` might return a long list of steps. Because of this, the maximum number of steps is set to a maximum of 4 to keep running time reasonable.

# %%
agent_registry = {
    "research_agent": research_agent,
    "editor_agent": editor_agent,
    "writer_agent": writer_agent,
}

def clean_json_block(raw: str) -> str:
    """
    Clean the contents of a JSON block that may come wrapped with Markdown backticks.
    """
    raw = raw.strip()
    if raw.startswith("```"):
        raw = re.sub(r"^```(?:json)?\n?", "", raw)
        raw = re.sub(r"\n?```$", "", raw)
    return raw.strip()

# %%
def executor_agent(topic, model: str = "openai:gpt-4o", limit_steps: bool = True):

    plan_steps = planner_agent(topic)
    max_steps = 4

    if limit_steps:
        plan_steps = plan_steps[:min(len(plan_steps), max_steps)]
    
    history = []

    print("==================================")
    print("🎯 Editor Agent")
    print("==================================")

    for i, step in enumerate(plan_steps):

        agent_decision_prompt = f"""
        You are an execution manager for a multi-agent research team.

        Given the following instruction, identify which agent should perform it and extract the clean task.

        Return only a valid JSON object with two keys:
        - "agent": one of ["research_agent", "editor_agent", "writer_agent"]
        - "task": a string with the instruction that the agent should follow

        Only respond with a valid JSON object. Do not include explanations or markdown formatting.

        Instruction: "{step}"
        """
        response = CLIENT.chat.completions.create(
            model=model,
            messages=[{"role": "user", "content": agent_decision_prompt}],
            temperature=0,
        )

        raw_content = response.choices[0].message.content
        cleaned_json = clean_json_block(raw_content)
        agent_info = json.loads(cleaned_json)

        agent_name = agent_info["agent"]
        task = agent_info["task"]

        context = "\n".join([
            f"Step {j+1} executed by {a}:\n{r}" 
            for j, (s, a, r) in enumerate(history)
        ])
        enriched_task = f"""
        You are {agent_name}.

        Here is the context of what has been done so far:
        {context}

        Your next task is:
        {task}
        """

        print(f"\n🛠️ Executing with agent: `{agent_name}` on task: {task}")

        if agent_name in agent_registry:
            output = agent_registry[agent_name](enriched_task)
            history.append((step, agent_name, output))
        else:
            output = f"⚠️ Unknown agent: {agent_name}"
            history.append((step, agent_name, output))

        print(f"✅ Output:\n{output}")

    return history

# %%
# If you want to see the full workflow without limiting the number of steps. Set limit_steps to False
# Keep in mind this could take more than 10 minutes to complete
executor_history = executor_agent("The ensemble Kalman filter for time series forecasting", limit_steps=True)

md = executor_history[-1][-1].strip("`")  
display(Markdown(md))
# Out:
# ==================================
# 🎯 Editor Agent
# ==================================
#
# 🛠️ Executing with agent: `research_agent` on task: Search the web, Wikipedia, and arXiv for papers on 'ensemble Kalman filter for time series forecasting'
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Here are the findings on the topic "ensemble Kalman filter for time series forecasting":
#
# ### arXiv Research Papers:
# 1. **"Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"**
#    - Authors: Zhidi Lin, Yiyong Sun, Feng Yin, Alexandre Hoang Thiéry
#    - Summary: The paper incorporates ensemble Kalman filter (EnKF) in Gaussian process state-space models to improve the efficiency of variational inference for online learning applications. [Read more](https://arxiv.org/abs/2312.05910v5)
#    - [PDF Link](https://arxiv.org/pdf/2312.05910v5)
#
# 2. **"LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"**
#    - Authors: Md Kowsher, Md. Shohanur Islam Sobuj, Nusrat Jahan Prottasha, E. Alejandro Alanis, Ozlem Ozmen Garibay, Niloofar Yousefi
#    - Summary: This paper presents the LLM-Mixer framework, which combines multiscale time-series decomposition with large language models to improve forecasting accuracy across various time scales. [Read more](https://arxiv.org/abs/2410.11674v2)
#    - [PDF Link](https://arxiv.org/pdf/2410.11674v2)
#
# 3. **Other related research**: Papers discussing different estimation schemes using Kalman filters and their improvements on forecasting models.
#
# ### Web Articles:
# 1. **Multi-Model Ensemble Kalman Filter**
#    - Discusses the combination of multiple model ensembles for data assimilation and forecasting using adaptive model error estimation. [Read more](https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2022MS003123)
#
# 2. **Combination with Dynamic Mode Decomposition**
#    - Shows how dynamic mode decomposition can be combined with EnKF to track and forecast dynamic systems effectively. [Read more](https://www.sciencedirect.com/science/article/pii/S0167278923000957)
#
# 3. **Understanding the Ensemble Kalman Filter**
#    - A tutorial on the EnKF, focusing on Bayesian inference for state-space models and its applications. [PDF Link](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)
#
# 4. **Forecasting Electricity Prices Using EnKF**
#    - An application of EnKF in forecasting electricity prices, demonstrating its utility in real-world datasets. [PDF Link](https://www.scienpress.com/Upload/JSEM/Vol%209_1_2.pdf)
#
# 5. **Wikipedia Overview**:
#    - [Ensemble Kalman Filter](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter) - A general overview of the EnKF and its applications in systems with large variable sets.
#
# ### Wikipedia Summary:
# - **Kalman Filter**: A statistical and control theory algorithm used for estimating unknown variables more accurately by processing multiple series of measurements over time. It has applications in navigation, control of vehicles, and more. [Read more](https://en.wikipedia.org/wiki/Kalman_filter)
#
# These sources provide a thorough overview of the ensemble Kalman filter and its applications in time series forecasting, both from theoretical and application perspectives.
# ✅ Output:
# Here are the findings on the topic "ensemble Kalman filter for time series forecasting":
#
# ### arXiv Research Papers:
# 1. **"Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"**
#    - Authors: Zhidi Lin, Yiyong Sun, Feng Yin, Alexandre Hoang Thiéry
#    - Summary: The paper incorporates ensemble Kalman filter (EnKF) in Gaussian process state-space models to improve the efficiency of variational inference for online learning applications. [Read more](https://arxiv.org/abs/2312.05910v5)
#    - [PDF Link](https://arxiv.org/pdf/2312.05910v5)
#
# 2. **"LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"**
#    - Authors: Md Kowsher, Md. Shohanur Islam Sobuj, Nusrat Jahan Prottasha, E. Alejandro Alanis, Ozlem Ozmen Garibay, Niloofar Yousefi
#    - Summary: This paper presents the LLM-Mixer framework, which combines multiscale time-series decomposition with large language models to improve forecasting accuracy across various time scales. [Read more](https://arxiv.org/abs/2410.11674v2)
#    - [PDF Link](https://arxiv.org/pdf/2410.11674v2)
#
# 3. **Other related research**: Papers discussing different estimation schemes using Kalman filters and their improvements on forecasting models.
#
# ### Web Articles:
# 1. **Multi-Model Ensemble Kalman Filter**
#    - Discusses the combination of multiple model ensembles for data assimilation and forecasting using adaptive model error estimation. [Read more](https://agupubs.onlinelibrary.wiley.com/doi/full/10.1029/2022MS003123)
#
# 2. **Combination with Dynamic Mode Decomposition**
#    - Shows how dynamic mode decomposition can be combined with EnKF to track and forecast dynamic systems effectively. [Read more](https://www.sciencedirect.com/science/article/pii/S0167278923000957)
#
# 3. **Understanding the Ensemble Kalman Filter**
#    - A tutorial on the EnKF, focusing on Bayesian inference for state-space models and its applications. [PDF Link](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)
#
# 4. **Forecasting Electricity Prices Using EnKF**
#    - An application of EnKF in forecasting electricity prices, demonstrating its utility in real-world datasets. [PDF Link](https://www.scienpress.com/Upload/JSEM/Vol%209_1_2.pdf)
#
# 5. **Wikipedia Overview**:
#    - [Ensemble Kalman Filter](https://en.wikipedia.org/wiki/Ensemble_Kalman_filter) - A general overview of the EnKF and its applications in systems with large variable sets.
#
# ### Wikipedia Summary:
# - **Kalman Filter**: A statistical and control theory algorithm used for estimating unknown variables more accurately by processing multiple series of measurements over time. It has applications in navigation, control of vehicles, and more. [Read more](https://en.wikipedia.org/wiki/Kalman_filter)
#
# These sources provide a thorough overview of the ensemble Kalman filter and its applications in time series forecasting, both from theoretical and application perspectives.
#
# 🛠️ Executing with agent: `research_agent` on task: Select the top five most relevant and cited papers from search results
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  Based on the recent search for the most relevant and cited papers on ensemble Kalman filter for time series forecasting, here are the top five papers and articles:
#
# 1. **"Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"**
#    - Authors: Zhidi Lin, Yiyong Sun, Feng Yin, Alexandre Hoang Thiéry
#    - Summary: Combines ensemble Kalman filter with Gaussian process state-space models for efficient online learning.
#    - [Read more](http://arxiv.org/abs/2312.05910v5) | [PDF Link](https://arxiv.org/pdf/2312.05910v5)
#
# 2. **"LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"**
#    - Authors: Md Kowsher, Md. Shohanur Islam Sobuj, Nusrat Jahan Prottasha, E. Alejandro Alanis, Ozlem Ozmen Garibay, Niloofar Yousefi
#    - Summary: Enhances forecasting accuracy by combining multiscale time-series analysis with large language models.
#    - [Read more](http://arxiv.org/abs/2410.11674v2) | [PDF Link](https://arxiv.org/pdf/2410.11674v2)
#
# 3. **"The Geometric Unscented Kalman Filter"**
#    - Authors: Chengling Fang, Jiang Liu, Songqing Ye, Ju Zhang
#    - Summary: Introduces a geometric unscented sampling strategy within the framework of the cubature Kalman filter for better accuracy and stability.
#    - [Read more](http://arxiv.org/abs/2009.13079v1) | [PDF Link](https://arxiv.org/pdf/2009.13079v1)
#
# 4. **Understanding the Ensemble Kalman Filter (University of Maryland Math Department)**
#    - Authors: Various
#    - Summary: A comprehensive understanding of the ensemble Kalman filter providing insight into Bayesian inference and the application of sequential Monte Carlo methods.
#    - [Read more](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)
#
# 5. **"A Multi-Model Ensemble Kalman Filter for Data Assimilation and Forecasting"**
#    - Authors: Eviatar Bach, Michael Ghil
#    - Summary: Proposes a multi-model ensemble Kalman filter for optimal data assimilation and forecasting in high-dimensional models.
#    - [Read more](https://centaur.reading.ac.uk/116990/1/J%20Adv%20Model%20Earth%20Syst%20-%202023%20-%20Bach%20-%20A%20Multi%E2%80%90Model%20Ensemble%20Kalman%20Filter%20for%20Data%20Assimilation%20and%20Forecasting.pdf)
#
# These papers have been recognized not only for their innovative approaches but also for the impact and citations they have received in the field of time series forecasting using ensemble Kalman filters.
# ✅ Output:
# Based on the recent search for the most relevant and cited papers on ensemble Kalman filter for time series forecasting, here are the top five papers and articles:
#
# 1. **"Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"**
#    - Authors: Zhidi Lin, Yiyong Sun, Feng Yin, Alexandre Hoang Thiéry
#    - Summary: Combines ensemble Kalman filter with Gaussian process state-space models for efficient online learning.
#    - [Read more](http://arxiv.org/abs/2312.05910v5) | [PDF Link](https://arxiv.org/pdf/2312.05910v5)
#
# 2. **"LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"**
#    - Authors: Md Kowsher, Md. Shohanur Islam Sobuj, Nusrat Jahan Prottasha, E. Alejandro Alanis, Ozlem Ozmen Garibay, Niloofar Yousefi
#    - Summary: Enhances forecasting accuracy by combining multiscale time-series analysis with large language models.
#    - [Read more](http://arxiv.org/abs/2410.11674v2) | [PDF Link](https://arxiv.org/pdf/2410.11674v2)
#
# 3. **"The Geometric Unscented Kalman Filter"**
#    - Authors: Chengling Fang, Jiang Liu, Songqing Ye, Ju Zhang
#    - Summary: Introduces a geometric unscented sampling strategy within the framework of the cubature Kalman filter for better accuracy and stability.
#    - [Read more](http://arxiv.org/abs/2009.13079v1) | [PDF Link](https://arxiv.org/pdf/2009.13079v1)
#
# 4. **Understanding the Ensemble Kalman Filter (University of Maryland Math Department)**
#    - Authors: Various
#    - Summary: A comprehensive understanding of the ensemble Kalman filter providing insight into Bayesian inference and the application of sequential Monte Carlo methods.
#    - [Read more](https://www.math.umd.edu/~slud/RITF17/enkf-tutorial.pdf)
#
# 5. **"A Multi-Model Ensemble Kalman Filter for Data Assimilation and Forecasting"**
#    - Authors: Eviatar Bach, Michael Ghil
#    - Summary: Proposes a multi-model ensemble Kalman filter for optimal data assimilation and forecasting in high-dimensional models.
#    - [Read more](https://centaur.reading.ac.uk/116990/1/J%20Adv%20Model%20Earth%20Syst%20-%202023%20-%20Bach%20-%20A%20Multi%E2%80%90Model%20Ensemble%20Kalman%20Filter%20for%20Data%20Assimilation%20and%20Forecasting.pdf)
#
# These papers have been recognized not only for their innovative approaches but also for the impact and citations they have received in the field of time series forecasting using ensemble Kalman filters.
# 🛠️ Executing with agent: `research_agent` on task: Extract abstracts, key methodology details, and performance metrics from each selected paper
# ==================================
# 🔍 Research Agent
# ==================================
# ✅ Output:
#  I have extracted the abstracts, key methodology details, and performance metrics for the selected papers on ensemble Kalman filter and related topics. Here are the details:
#
# ### 1. "Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"
# - **Abstract**: The paper addresses the challenges of using Gaussian process state-space models (GPSSMs) for nonlinear dynamical systems under non-mean-field assumptions. It integrates the ensemble Kalman filter (EnKF) into a variational inference framework to improve posterior distribution approximations. This approach facilitates efficient online learning and offers a closed-form approximation of the evidence lower bound (ELBO). The new algorithm promotes data-fitting accuracy and incorporates model regularizations to reduce overfitting. Evaluations demonstrate the superior learning and inference performance of the EnKF-aided variational inference algorithms over existing methods.
# - **Methodology**: Incorporation of EnKF in GPSSM for improving variational inference efficiency under realistic conditions like the non-mean-field assumption.
# - **Performance Metrics**: Shows superior performance across diverse datasets, both real and synthetic, compared to existing methods.
# - **[PDF Link](https://arxiv.org/pdf/2312.05910v5)**
#
# ### 2. "LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"
# - **Abstract**: This research deals with improving time series forecasting through LLM-Mixer, a framework coupling multiscale time-series decomposition with pre-trained Large Language Models (LLMs). The framework processes data at different temporal resolutions and delivers high-performance forecasting by leveraging short-term fluctuations and long-term trends.
# - **Methodology**: Uses multiscale time-series decomposition with frozen LLMs, guided by specific textual prompts for time-series data.
# - **Performance Metrics**: Achieves competitive forecasting performance, surpassing recent state-of-the-art models across different horizons.
# - **[PDF Link](https://arxiv.org/pdf/2410.11674v2)**
#
# ### 3. "The Geometric Unscented Kalman Filter"
# - **Abstract**: Introduces a new filtering scheme named the Geometric Unscented Kalman Filter (GUF), combining the strengths of cubature Kalman filter (CKF) and Gauss-Hermite filter (GHF), maintaining stability while using positive weights for adequate accuracy. GUF features a geometric unscented sampling (GUS) strategy that enhances filtering efficiency compared to traditional methods.
# - **Methodology**: Combines deterministic sampling methods, similar to CKF and UKF, retaining positive weights akin to particle filters.
# - **Performance Metrics**: Offers adequate accuracy and maintains stability without suffering from sample size issues typical in particle filters.
# - **[PDF Link](https://arxiv.org/pdf/2009.13079v1)**
#
# ### 4. "A Multi-Model Ensemble Kalman Filter for Data Assimilation and Forecasting"
# - **Abstract**: The paper discusses a multi-model ensemble Kalman filter designed for optimal data assimilation and forecasting in high-dimensional models. The filter's application serves to adapt and improve model forecasting accuracy by utilizing multiple ensemble models.
# - **Methodology**: Employs a multi-model approach to refine ensemble forecast accuracy, crucial for high-dimensional models.
# - **Performance Metrics**: Enhanced data assimilation and forecasting capabilities in complex model settings.
# - **Note**: The detailed extracted abstract and performance specifics were not available from the search, as the document retrieved did not relate directly to the query (potentially mismatched or unavailable detailed summary data).
#
# These summaries provide an overview of each paper's focus, methods, and achievements in employing and advancing Kalman filter techniques in time series forecasting.
# ✅ Output:
# I have extracted the abstracts, key methodology details, and performance metrics for the selected papers on ensemble Kalman filter and related topics. Here are the details:
#
# ### 1. "Ensemble Kalman Filtering Meets Gaussian Process SSM for Non-Mean-Field and Online Inference"
# - **Abstract**: The paper addresses the challenges of using Gaussian process state-space models (GPSSMs) for nonlinear dynamical systems under non-mean-field assumptions. It integrates the ensemble Kalman filter (EnKF) into a variational inference framework to improve posterior distribution approximations. This approach facilitates efficient online learning and offers a closed-form approximation of the evidence lower bound (ELBO). The new algorithm promotes data-fitting accuracy and incorporates model regularizations to reduce overfitting. Evaluations demonstrate the superior learning and inference performance of the EnKF-aided variational inference algorithms over existing methods.
# - **Methodology**: Incorporation of EnKF in GPSSM for improving variational inference efficiency under realistic conditions like the non-mean-field assumption.
# - **Performance Metrics**: Shows superior performance across diverse datasets, both real and synthetic, compared to existing methods.
# - **[PDF Link](https://arxiv.org/pdf/2312.05910v5)**
#
# ### 2. "LLM-Mixer: Multiscale Mixing in LLMs for Time Series Forecasting"
# - **Abstract**: This research deals with improving time series forecasting through LLM-Mixer, a framework coupling multiscale time-series decomposition with pre-trained Large Language Models (LLMs). The framework processes data at different temporal resolutions and delivers high-performance forecasting by leveraging short-term fluctuations and long-term trends.
# - **Methodology**: Uses multiscale time-series decomposition with frozen LLMs, guided by specific textual prompts for time-series data.
# - **Performance Metrics**: Achieves competitive forecasting performance, surpassing recent state-of-the-art models across different horizons.
# - **[PDF Link](https://arxiv.org/pdf/2410.11674v2)**
#
# ### 3. "The Geometric Unscented Kalman Filter"
# - **Abstract**: Introduces a new filtering scheme named the Geometric Unscented Kalman Filter (GUF), combining the strengths of cubature Kalman filter (CKF) and Gauss-Hermite filter (GHF), maintaining stability while using positive weights for adequate accuracy. GUF features a geometric unscented sampling (GUS) strategy that enhances filtering efficiency compared to traditional methods.
# - **Methodology**: Combines deterministic sampling methods, similar to CKF and UKF, retaining positive weights akin to particle filters.
# - **Performance Metrics**: Offers adequate accuracy and maintains stability without suffering from sample size issues typical in particle filters.
# - **[PDF Link](https://arxiv.org/pdf/2009.13079v1)**
#
# ### 4. "A Multi-Model Ensemble Kalman Filter for Data Assimilation and Forecasting"
# - **Abstract**: The paper discusses a multi-model ensemble Kalman filter designed for optimal data assimilation and forecasting in high-dimensional models. The filter's application serves to adapt and improve model forecasting accuracy by utilizing multiple ensemble models.
# - **Methodology**: Employs a multi-model approach to refine ensemble forecast accuracy, crucial for high-dimensional models.
# - **Performance Metrics**: Enhanced data assimilation and forecasting capabilities in complex model settings.
# - **Note**: The detailed extracted abstract and performance specifics were not available from the search, as the document retrieved did not relate directly to the query (potentially mismatched or unavailable detailed summary data).
#
# These summaries provide an overview of each paper's focus, methods, and achievements in employing and advancing Kalman filter techniques in time series forecasting.
#
# 🛠️ Executing with agent: `writer_agent` on task: Draft an introduction section outlining the research problem, motivation, and objectives
# ==================================
# ✍️ Writer Agent
# ==================================
# ✅ Output:
# ## Introduction
#
# Accurate time series forecasting is a critical task across various domains, including finance, meteorology, and supply chain management. However, the inherent non-linear nature and uncertainty within time series data present significant challenges for traditional forecasting models. To address these challenges, advanced data assimilation techniques, such as the ensemble Kalman filter (EnKF), have been increasingly employed due to their robustness and adaptability in dynamic settings.
#
# The ensemble Kalman filter is a sophisticated extension of the classical Kalman filter, which has been effective in linear systems. By leveraging multiple ensemble members, the EnKF can tackle non-linearity more effectively, providing realistic estimates of uncertainty and improving forecasting accuracy. Despite its strengths, the application of EnKF in time series forecasting is not devoid of challenges. The need to adapt to varying data patterns and integrate with modern computational methods remains a critical research focus.
#
# The increasing complexity of real-world datasets necessitates the development of hybrid models that combine EnKF with other state-of-the-art techniques, such as Gaussian Processes and Large Language Models, to enhance predictive performance. The motivation for this research stems from the limitations observed in conventional time series models when addressing complex, multi-scale data. By incorporating EnKF with auxiliary models, we aim to overcome these limitations, harnessing the strengths of each approach.
#
# This paper explores several innovative methodologies incorporating the ensemble Kalman filter in time series forecasting. Each methodology aims to address the overarching objective of improving forecast accuracy and reliability while providing insights into model adaptability in diverse, high-dimensional settings. This research intends to assess the efficacy of these hybrid models, thereby contributing to the broader field of time series analysis and forecasting. Through these advancements, we seek to provide robust tools for decision-makers in fields where timely, accurate forecasting is paramount.
# ## Introduction
#
# Accurate time series forecasting is a critical task across various domains, including finance, meteorology, and supply chain management. However, the inherent non-linear nature and uncertainty within time series data present significant challenges for traditional forecasting models. To address these challenges, advanced data assimilation techniques, such as the ensemble Kalman filter (EnKF), have been increasingly employed due to their robustness and adaptability in dynamic settings.
#
# The ensemble Kalman filter is a sophisticated extension of the classical Kalman filter, which has been effective in linear systems. By leveraging multiple ensemble members, the EnKF can tackle non-linearity more effectively, providing realistic estimates of uncertainty and improving forecasting accuracy. Despite its strengths, the application of EnKF in time series forecasting is not devoid of challenges. The need to adapt to varying data patterns and integrate with modern computational methods remains a critical research focus.
#
# The increasing complexity of real-world datasets necessitates the development of hybrid models that combine EnKF with other state-of-the-art techniques, such as Gaussian Processes and Large Language Models, to enhance predictive performance. The motivation for this research stems from the limitations observed in conventional time series models when addressing complex, multi-scale data. By incorporating EnKF with auxiliary models, we aim to overcome these limitations, harnessing the strengths of each approach.
#
# This paper explores several innovative methodologies incorporating the ensemble Kalman filter in time series forecasting. Each methodology aims to address the overarching objective of improving forecast accuracy and reliability while providing insights into model adaptability in diverse, high-dimensional settings. This research intends to assess the efficacy of these hybrid models, thereby contributing to the broader field of time series analysis and forecasting. Through these advancements, we seek to provide robust tools for decision-makers in fields where timely, accurate forecasting is paramount.

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
