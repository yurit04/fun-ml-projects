# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
from PIL import Image
from IPython.display import display

# Filter harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# TEST YOUR VERSION OF PILLOW
# Run this cell. If you see a picture of a cat you're all set!
with Image.open('../data/CATS_DOGS/test/CAT/10107.jpg') as im:
    display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=86x86 at 0x7FEBC5952048>

# %%
path = '../data/CATS_DOGS/'
img_names = []

for folder, subfolders, filenames in os.walk(path):
    for img in filenames:
        img_names.append(folder+'/'+img)
        
print('Images: ',len(img_names))
# Out:
# Images:  24996

# %%
img_sizes = []
rejected = []

for item in img_names:
    try:
        with Image.open(item) as img:
            img_sizes.append(img.size)
    except:
        rejected.append(item)
        
print(f'Images:  {len(img_sizes)}')
print(f'Rejects: {len(rejected)}')
# Out:
# Images:  24994
# Rejects: 2

# %%
dog = Image.open('../data/CATS_DOGS/train/DOG/14.jpg')
print(dog.size)
display(dog)
# Out:
# (500, 387)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x387 at 0x7FEBC744FCC0>
