# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LSTM

# %%
tf.__version__
# Out:
# '2.4.1'

# %%
X = np.linspace(0,100,10000)
X.shape
# Out:
# (10000,)

# %%
y = np.sin(X)

# %%
plt.figure(figsize=(16,4))
plt.plot(X,y)
plt.grid()

# %%
Length = X.shape[0]
TrainLength = Length * 70 // 100

X_train = X[:TrainLength]
y_train = y[:TrainLength]

X_test = X[TrainLength:]
y_test = y[TrainLength:]

# %%
plt.figure(figsize=(16,4))
plt.plot(X_train,y_train)
plt.grid()

# %%
plt.figure(figsize=(16,4))
plt.plot(X_test,y_test)
plt.grid()

# %%
model = Sequential(name='fx')

activation = 'elu'
dropout = 0.4

# model.add(Dense(100))
# model.add(tf.keras.layers.LeakyReLU(alpha=0.03))
# model.add(Dense(100))
# model.add(tf.keras.layers.LeakyReLU(alpha=0.03))
# model.add(Dense(100))
# model.add(tf.keras.layers.LeakyReLU(alpha=0.03))
# model.add(Dense(100))
# model.add(tf.keras.layers.LeakyReLU(alpha=0.03))

model.add(Dense(100,activation=activation))
model.add(Dense(100,activation=activation))
model.add(Dense(100,activation=activation))

model.add(Dense(1))

model.compile(loss='mse',optimizer='adam')

model.fit(X_train,y_train,epochs=50,validation_data=(X_test,y_test))
# Out:
# Epoch 1/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.9798 - val_loss: 0.5177
# Epoch 2/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5219 - val_loss: 0.8291
# Epoch 3/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5406 - val_loss: 0.5469
# Epoch 4/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5089 - val_loss: 0.5302
# Epoch 5/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4970 - val_loss: 0.5175
# Epoch 6/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.5118 - val_loss: 0.5405
# Epoch 7/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5096 - val_loss: 0.6865
# Epoch 8/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5021 - val_loss: 0.5274
# Epoch 9/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4803 - val_loss: 0.5515
# Epoch 10/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4789 - val_loss: 0.5163
# Epoch 11/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4637 - val_loss: 0.5320
# Epoch 12/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4657 - val_loss: 0.5131
# Epoch 13/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4527 - val_loss: 0.6173
# Epoch 14/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4459 - val_loss: 0.5312
# Epoch 15/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4488 - val_loss: 0.5130
# Epoch 16/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4414 - val_loss: 0.5336
# Epoch 17/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4442 - val_loss: 0.5770
# Epoch 18/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4304 - val_loss: 0.5231
# Epoch 19/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4376 - val_loss: 0.5790
# Epoch 20/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4279 - val_loss: 0.5273
# Epoch 21/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4301 - val_loss: 0.5133
# Epoch 22/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4257 - val_loss: 0.5432
# Epoch 23/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4237 - val_loss: 0.5150
# Epoch 24/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4293 - val_loss: 0.5134
# Epoch 25/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4277 - val_loss: 0.5271
# Epoch 26/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4219 - val_loss: 0.5192
# Epoch 27/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4084 - val_loss: 0.5149
# Epoch 28/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4174 - val_loss: 0.5229
# Epoch 29/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4148 - val_loss: 0.5193
# Epoch 30/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4031 - val_loss: 0.5288
# Epoch 31/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4071 - val_loss: 0.5196
# Epoch 32/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4230 - val_loss: 0.5185
# Epoch 33/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4122 - val_loss: 0.5145
# Epoch 34/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4148 - val_loss: 0.5320
# Epoch 35/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4009 - val_loss: 0.5159
# Epoch 36/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4031 - val_loss: 0.5336
# Epoch 37/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4025 - val_loss: 0.5136
# Epoch 38/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3920 - val_loss: 0.5144
# Epoch 39/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3843 - val_loss: 0.5574
# Epoch 40/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3877 - val_loss: 0.5240
# Epoch 41/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3867 - val_loss: 0.5165
# Epoch 42/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3880 - val_loss: 0.5167
# Epoch 43/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3938 - val_loss: 0.5164
# Epoch 44/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3802 - val_loss: 0.5391
# Epoch 45/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3942 - val_loss: 0.5177
# Epoch 46/50
# 219/219 [==============================] - 1s 3ms/step - loss: 0.3844 - val_loss: 0.5169
# Epoch 47/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3711 - val_loss: 0.5315
# Epoch 48/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3587 - val_loss: 0.5316
# Epoch 49/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3789 - val_loss: 0.5148
# Epoch 50/50
# 219/219 [==============================] - 1s 2ms/step - loss: 0.3726 - val_loss: 0.5139

# %%
metrics = pd.DataFrame(model.history.history)
metrics[['loss','val_loss']].plot()
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(X)

plt.figure(figsize=(16,4))
plt.plot(X,y_pred)
plt.plot(X,y)
plt.plot(X_train,y_train)
plt.grid()
